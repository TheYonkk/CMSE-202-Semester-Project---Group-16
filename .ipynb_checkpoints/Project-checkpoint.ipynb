# %% [markdown]
# # Analysis and Prediction of Oil Pressure in a Student-Built Race Car
# #### Dave, Luke, Victor, Henry

# %% [markdown]
# The goal of this project is to create a model that determines if the current oil pressure in a racing engine is acceptable. By using previously recorded data from the MSU Formula Racing Team, a model will be created using instances of good and poor oil pressure.
#
# Once a model is created, it can be used to analyze data in real-time on the MSU race car. If poor oil-pressure is detected, the driver can be notified - perhaps saving an engine from destruction and a driver from injury.

# %% [markdown]
# ## Load the Data

# %% [markdown]
# The data below was provided by Dave, a member of the formula racing team. There are two files loaded: one that had an instance of good oil pressure, and one that had an insance of bad oil pressure. The x-axis is time, as all car data is collected in reference to time.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from load_data import load_windarab_log

column_labels = ['Time', 'Engine Temp', 'Oil Pressure', 'Oil Temp', 'RPM']


# good oil pressure in this log
data1_path = "data/STT1_data_log.txt"
print("Good data log:")
data1_df = load_windarab_log(data1_path, column_labels, True)

# bad oil pressure in this log
data2_path = "data/ford_data_log.txt"
print("Bad data log:")
data2_df = load_windarab_log(data2_path, column_labels, True)
# Out:
# Good data log:
# /Users/daveyonkers/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# Bad data log:

# %% [markdown]
# ## Find a period of good oil pressure

# %% [markdown]
# In order to train our model, we will want to trim down the data into a period of time that represents good oil pressure. You can tell that the oil pressure is good because it changes rapidly with the engine RPM.

# %%
data1_df[100:200]

data1_start_time = 100
data1_end_time = 180

#plt.plot(data1_df[data1_start_time:data1_end_time].index, data1_df[data1_start_time:data1_end_time]["Oil Pressure"])

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('time (s)')
ax1.set_ylabel('RPM', color=color)
ax1.plot(data1_df[data1_start_time:data1_end_time].index, data1_df[data1_start_time:data1_end_time]["RPM"], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Oil Pressure [psi]', color=color)  # we already handled the x-label with ax1
ax2.plot(data1_df[data1_start_time:data1_end_time].index, data1_df[data1_start_time:data1_end_time]["Oil Pressure"], color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title("Good Oil Pressure")
plt.show()

# %% [markdown]
# ## Find a period of bad oil pressure
# It is easy to tell if there is bad oil pressure then the engine does not supply itself enough oil. Essentially, this means that the oil trace is much different than the RPM trace. Here, we select a period of poor engine lubrication.

# %%
data2_start_time = 655
data2_end_time = 685

#plt.plot(data1_df[data1_start_time:data1_end_time].index, data1_df[data1_start_time:data1_end_time]["Oil Pressure"])

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('time (s)')
ax1.set_ylabel('RPM', color=color)
ax1.plot(data2_df[data2_start_time:data2_end_time].index, data2_df[data2_start_time:data2_end_time]["RPM"], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Oil Pressure [psi]', color=color)  # we already handled the x-label with ax1
ax2.plot(data2_df[data2_start_time:data2_end_time].index, data2_df[data2_start_time:data2_end_time]["Oil Pressure"], color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %% [markdown]
# ## Creating Feature Vectors and Label Vectors to Train the Model

# %% [markdown]
# To train the model, we'll need to assign labels to our data as well as format the data into feature vectors.

# %%
# using the time periods discovered above, here we create dataframes only containing information
# from those periods
df_good = data1_df[data1_start_time:data1_end_time]
df_bad = data2_df[data2_start_time:data2_end_time]

# %%
# create a new column named 'flag' that will hold a one or a zero, depending on if the data is bad or good
df_good.insert(4, "Flag", 0) 
df_bad.insert(4, "Flag", 1)

# %%
# combine both data frames into one that we can shuffle.
df_all = pd.concat([df_good, df_bad])

from sklearn.utils import shuffle
df_all = shuffle(df_all)

df_all.head()
# Out:
#         Engine Temp  Oil Pressure  Oil Temp      RPM  Flag
# Time
# 158.89        103.4          47.9     114.9  11380.0     0
# 114.72        100.9          29.1     111.5   8021.0     0
# 682.98        105.0          12.0     114.6   9645.0     1
# 666.18         99.0          20.9     110.6  13203.0     1
# 100.90         99.8          29.5     109.8   6982.0     0

# %%
# create the feature vectors by pulling out the unecessary data and turning them into arrays
features_df = df_all.drop('Flag', axis=1)
labels_df = df_all.drop(['Engine Temp', 'Oil Pressure', 'Oil Temp', 'RPM'], axis=1)
feature_vectors = np.asarray(features_df)
label_vectors = np.asarray(labels_df)

# %%
# perform a train-test split on the data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(feature_vectors, label_vectors, test_size=0.25, random_state=42)

# this ensures that the data is in the correct format for the model training and testing
y_train = y_train.ravel()
y_test = y_test.ravel()

# %% [markdown]
# ## Model Selection and Training

# %% [markdown]
# We chose a support vector machine learning model in-part because of its simplicity (as shown why later), but also because of it's effectiveness in high-dimentional applications. Here, we only train a model based off of oil pressure, engine rpm, oil temperature, and engine temperature, however we could add many more signals if we would like. Also, we chose a classfication model because we're not really interested in the details of a prediction, we just want to know if it fits into a good or bad class (a binary application).

# %%
from sklearn.svm import SVC

# create the model object
clf = SVC(kernel='linear')

# train the model
clf.fit(X_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# ## Testing the Model
# Well, training the model was easy! Let's see how well it holds up against our testing split.

# %%
# get predictions based upon our newly trained model
y_predict = clf.predict(X_test)

# %%
# calculcate the accuracy of the predictions
from sklearn.metrics import accuracy_score

print("The accuracy of the model is {}/1.0".format(accuracy_score(y_test, y_predict)))
# Out:
# The accuracy of the model is 1.0/1.0

# %%
from sklearn.metrics import plot_confusion_matrix

class_names = ['Good Oil Pressure', 'Poor Oil Pressure']

plot_confusion_matrix(clf, X_test, y_test, display_labels=class_names, cmap=plt.cm.Blues, 
                     normalize='true')

# %% [markdown]
# ### Testing Results
# You can see that the model performs with 100% accuracy! Wow! Well, there are some caviots here. We chose VERY definitive areas of good and bad oil pressure, and it's easy to see in the first couple of plots in this notebook. The real test of the model will come with real-life and real-time testing! Read below on how this will be achieved.

# %% [markdown]
# ## Learning How to Create Predictions Without the `predict()` Method

# %% [markdown]
# After a scavenging the internet, I learned how the `predict` method actually worked. With a linear classification kernal and binary outputs, it's not so hard once you know the support vector coefficients and the hyperplane intercept.
#
# $$\omega \cdot x_{i} + b$$
#
# What's a hyperplane? Well, a hyperplane is a plane that, in our case, seperates the good data points from the bad data points. We can calculcate how far a point is away from the hyperplane by calculating the dot product of our classifier coefficients and a test vector in question, then adding the intercept. The result is a number, and that number represents the distance of that point to the hyperplane. In our case, if the result is negative, it's below the hyperplane and tagged a value of 1 (bad oil pressure). Conversely, if it's above the hyperplane, it's given the value of 0 (good oil pressure).

# %%
print("The coefficients from the SVM model are: {}".format(clf.coef_[0]))
print("The intercept from the model is: {}".format(clf.intercept_[0]))
# Out:
# The coefficients from the SVM model are: [-4.02807974 -3.27391737 -2.18064598  0.00767715]
# The intercept from the model is: 663.5209047953625

# %% [markdown]
# ### Our equation
# With the given equation, we can can calculate the result with numpy, shown in the following line

# %%
np.dot(clf.coef_[0], X_test[1]) + clf.intercept_[0]
# Out:
# 37.96298716251795

# %% [markdown]
# ### Comparing our equation to scikit calculations

# %%
my_predictions = []
for fvec in X_test:
    
    # calculate the decision value
    result = np.dot(clf.coef_[0], fvec) + clf.intercept_[0]
    
    # decide if it was above or below the hyperplane
    if result >= 0:
        my_predictions.append(1)
    else:
        my_predictions.append(0)

# here, I compare my predictions the the predications made by the scikit library. You can see that they are the
# same (for the first 100 values, anyways. But, you get the point... it's the same calculation method)
(np.asarray(my_predictions) == clf.predict(X_test))[0:100]
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %% [markdown]
# ## Embedding the Model in Electronics
# Unfortunately, embedded electronics can't run Jupyter Notebooks, or even Python! What are embedded electronics? Well, they're essentially the tiny microchips that you find in microwaves, refridgerators, washing machines, and even cars. They are devices that include tiny computers called microcontrollers. Typically, microcontrollers are programmed with C or C++, but fear not, all we need to do is write a tiny little function in order to embed our model.

# %% [markdown]
# ```cpp
# bool predict(float weights_vect[], int weights_vect_size, float intercept, float test_vect[]){
#
#   // create a temporary variable to store our running calculation
#   float calc = 0;
#
#   // calculate the dot product for weights_vect[] and test_vect[]
#   for (int i = 0; i < weights_vect_size; i++){
#     calc += weights_vect[i] * test_vect[i];
#   }
#
#   // add the intercept
#   calc += intercept;
#
#   // classify the calculation as either a 1 or a 0
#   if (calc >= 0){
#     return 1;
#   } else {
#     return 0;
#   }
# }
# ```

# %% [markdown]
# ## Real-life Results!

# %% [markdown]
# Unfortunately, as a result of the coronavirus pandemic, we were unable to test our model on the physical car. However, Dave had the idea of this project months ago, and build the support software for the machine learning model on the car's hardware!
#
# Below is a picture of the 2019 MSU Formula Racing Team challenger, SR-19. Dave took this photo during a late-night testing session of the clear-resevoir oil system (illuminated by the flashlight).
#
# Also shown is a picture of the driver display! This is hand built and programmed by members on the team. The picture is of what the driver would be shown if there _was_ an oil pressure issue. It's sad that we weren't able to test the model in real-life, but hopefully we can soon!

# %% [markdown]
# <img src="https://live.staticflickr.com/65535/49127949753_5c58735146_b.jpg" alt="oil testing" width="750"/>
# <img src="https://live.staticflickr.com/65535/49650505352_4068629cb9_b.jpg" alt="driver display" width="350"/>
